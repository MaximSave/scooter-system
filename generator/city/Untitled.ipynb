# %%
# %pip install osmnx
# Out:
# Collecting osmnx
#   Downloading osmnx-2.0.7-py3-none-any.whl.metadata (4.9 kB)
# Collecting geopandas>=1.0.1 (from osmnx)
#   Downloading geopandas-1.1.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: networkx>=2.5 in c:\users\maxim\anaconda3\envs\rnn\lib\site-packages (from osmnx) (3.3)
# Requirement already satisfied: numpy>=1.22 in c:\users\maxim\anaconda3\envs\rnn\lib\site-packages (from osmnx) (1.26.4)
# Requirement already satisfied: pandas>=1.4 in c:\users\maxim\anaconda3\envs\rnn\lib\site-packages (from osmnx) (2.3.3)
# Requirement already satisfied: requests>=2.27 in c:\users\maxim\anaconda3\envs\rnn\lib\site-packages (from osmnx) (2.32.5)
# Collecting shapely>=2.0 (from osmnx)
#   Downloading shapely-2.1.2-cp310-cp310-win_amd64.whl.metadata (7.1 kB)
# Collecting pyogrio>=0.7.2 (from geopandas>=1.0.1->osmnx)
#   Downloading pyogrio-0.12.1-cp310-cp310-win_amd64.whl.metadata (6.0 kB)
# Requirement already satisfied: packaging in c:\users\maxim\anaconda3\envs\rnn\lib\site-packages (from geopandas>=1.0.1->osmnx) (25.0)
# Collecting pyproj>=3.5.0 (from geopandas>=1.0.1->osmnx)
#   Downloading pyproj-3.7.1-cp310-cp310-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maxim\anaconda3\envs\rnn\lib\site-packages (from pandas>=1.4->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maxim\anaconda3\envs\rnn\lib\site-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\maxim\anaconda3\envs\rnn\lib\site-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: certifi in c:\users\maxim\anaconda3\envs\rnn\lib\site-packages (from pyogrio>=0.7.2->geopandas>=1.0.1->osmnx) (2025.10.5)
# Requirement already satisfied: six>=1.5 in c:\users\maxim\anaconda3\envs\rnn\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4->osmnx) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\maxim\anaconda3\envs\rnn\lib\site-packages (from requests>=2.27->osmnx) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maxim\anaconda3\envs\rnn\lib\site-packages (from requests>=2.27->osmnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\maxim\anaconda3\envs\rnn\lib\site-packages (from requests>=2.27->osmnx) (2.5.0)
# Downloading osmnx-2.0.7-py3-none-any.whl (101 kB)
# Downloading geopandas-1.1.1-py3-none-any.whl (338 kB)
# Downloading pyogrio-0.12.1-cp310-cp310-win_amd64.whl (22.9 MB)
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#     --------------------------------------- 0.5/22.9 MB 2.4 MB/s eta 0:00:10
#    -- ------------------------------------- 1.6/22.9 MB 4.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 2.6/22.9 MB 4.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 2.9/22.9 MB 4.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 2.9/22.9 MB 4.7 MB/s eta 0:00:05
#    ------ --------------------------------- 3.9/22.9 MB 3.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 6.8/22.9 MB 4.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 6.8/22.9 MB 4.9 MB/s eta 0:00:04
#    ------------- -------------------------- 7.6/22.9 MB 4.3 MB/s eta 0:00:04
#    ------------------ --------------------- 10.5/22.9 MB 5.2 MB/s eta 0:00:03
#    ------------------ --------------------- 10.7/22.9 MB 5.0 MB/s eta 0:00:03
#    --------------------- ------------------ 12.1/22.9 MB 4.9 MB/s eta 0:00:03
#    ------------------------ --------------- 13.9/22.9 MB 5.2 MB/s eta 0:00:02
#    -------------------------- ------------- 15.5/22.9 MB 5.3 MB/s eta 0:00:02
#    --------------------------- ------------ 15.7/22.9 MB 5.4 MB/s eta 0:00:02
#    --------------------------- ------------ 16.0/22.9 MB 4.9 MB/s eta 0:00:02
#    -------------------------------- ------- 18.9/22.9 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 19.7/22.9 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------- -- 21.2/22.9 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  22.8/22.9 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 22.9/22.9 MB 5.4 MB/s  0:00:04
# Downloading pyproj-3.7.1-cp310-cp310-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    -------- ------------------------------- 1.3/6.3 MB 6.7 MB/s eta 0:00:01
#    --------------- ------------------------ 2.4/6.3 MB 5.8 MB/s eta 0:00:01
#    ------------------------- -------------- 3.9/6.3 MB 6.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.5/6.3 MB 6.2 MB/s eta 0:00:01
#    ------------------------------------ --- 5.8/6.3 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 5.5 MB/s  0:00:01
# Downloading shapely-2.1.2-cp310-cp310-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------ --------- 1.3/1.7 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 7.2 MB/s  0:00:00
# Installing collected packages: shapely, pyproj, pyogrio, geopandas, osmnx
#
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    ---------------------------------------- 0/5 [shapely]
#    -------- ------------------------------- 1/5 [pyproj]
#    -------- ------------------------------- 1/5 [pyproj]
#    ---------------- ----------------------- 2/5 [pyogrio]
#    ---------------- ----------------------- 2/5 [pyogrio]
#    ---------------- ----------------------- 2/5 [pyogrio]
#    ---------------- ----------------------- 2/5 [pyogrio]
#    ---------------- ----------------------- 2/5 [pyogrio]
#    ------------------------ --------------- 3/5 [geopandas]
#    ------------------------ --------------- 3/5 [geopandas]
#    ------------------------ --------------- 3/5 [geopandas]
#    -------------------------------- ------- 4/5 [osmnx]
#    ---------------------------------------- 5/5 [osmnx]
#
# Successfully installed geopandas-1.1.1 osmnx-2.0.7 pyogrio-0.12.1 pyproj-3.7.1 shapely-2.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import osmnx as ox

ox.settings.overpass_endpoint = "https://overpass.kumi.systems/api/interpreter"
ox.settings.requests_timeout = 180
ox.settings.overpass_rate_limit = True

G = ox.graph_from_place(
    "Moscow, Russia",
    network_type="walk",
    simplify=True
)

# %%
with open("moscow_graph.pkl", "wb") as f:
    pickle.dump(G, f)

# %%
import osmnx as ox
import logging

ox.settings.log_console = True
ox.settings.use_cache = True
ox.settings.overpass_endpoint = "https://overpass.kumi.systems/api/interpreter"
ox.settings.requests_timeout = 180
ox.settings.overpass_rate_limit = True

logging.basicConfig(level=logging.INFO)

G = ox.graph_from_place(
    "Moscow, Russia",
    network_type="walk",
    simplify=True
)

# %%
import osmnx as ox

ox.settings.overpass_endpoint = "https://overpass.kumi.systems/api/interpreter"
ox.settings.requests_timeout = 180
ox.settings.overpass_rate_limit = True

G = ox.graph_from_place(
    "Moscow, Russia",
    network_type="walk",
    simplify=True
)

with open("moscow_graph.pkl", "wb") as f:
    pickle.dump(G, f)
